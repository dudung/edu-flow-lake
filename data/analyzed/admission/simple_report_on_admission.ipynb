# %% [markdown]
# # simple report on admission

# %% [markdown]
# ## data
# Following data is collected from 2001 until 2020.

# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.read_excel('rejection_rate.xlsx')
# Out:
#    semester  batches  applied  accepted  rejection
# 0    2001_1        1        5         4       0.20
# 1    2002_1        2       10         3       0.70
# 2    2003_1        2       15         7       0.53
# 3    2004_1        2       20         6       0.70
# 4    2005_1        3       25        12       0.52
# 5    2006_1        2       20         7       0.65
# 6    2006_2        2       10         2       0.80
# 7    2007_1        3       25         9       0.64
# 8    2007_2        2       15         1       0.93
# 9    2008_1        3       25        11       0.56
# 10   2008_2        3       20         4       0.80
# 11   2009_1        3       30        14       0.53
# 12   2009_2        3       25         6       0.76
# 13   2010_1        3       35        13       0.63
# 14   2010_2        3       25         9       0.64
# 15   2011_1        3       40        14       0.65
# 16   2011_2        3       20         6       0.70
# ...

# %% [markdown]
# ## admission
# It start at 2001 only in first semester until 2005. From 2006 there are two addmission in a year, in the first and second semesters. Data for number of batches, total applicants and accepted applicants are given in previous table.

# %% [markdown]
# ## rejection rate
# Rejection rate (RR) is defined as
#
# $$\tag{1}
# {\rm RR} = \frac{\rm accepted \ applicants}{\rm total \ applicants}.
# $$
#
# Equation (1) can be multiplied with 100 to get the result in percentage.

# %% [markdown]
#  In order to get insight during 2001 - 2020 following are RR for every semester
#
#  ![](rejection_rate_semester.png)
#
#  The lowest RR is 0.2 and it occurs on 2001_1 and 2016_1 semesters. And the highest is about 0.9 and it happes on 2007_2 semester.

# %% [markdown]
# ## batches
# To accommodate more applicants several batches are offered in each semester.
#
# ![](number_of_batches_semester.png)
#
# Number of batches varies from 1 to 4 for each semester as shown above.

# %% [markdown]
# # batches and rr
# Higher rejection rate RR tells us the only few applicants are accepted. Does it has relation with number of batches?
#
# ![](rejection_rate_number_of_batches.png)
#
# Above figures shows that only one semester with one batch gives about 0.7 rejection rate (or 70%), the other semesters requires at least 2 semester to get rejection rate above 0.5 (or 50%).

# %% [markdown]
# ## another relation
# From available data relation between number of batches, total applicants, and rejection rate can be obtained as follow.
#
# ![](number_of_batches_applied_rejection.png)
#
# Horizontal axis is showing total applicants that applied in certain semester and vertical axis is showing number of batches of related semester. The markers give additional dimension using color and size, which relates to rejection rate. Smaller size and more blue colored indicates lower rejection rate, while larger size and more red colored indicates higher rejection rate.
#
# Some findings
# - number of batches equal to one can give lower or higher rejection rate.
# - the highest rejection rate is when number of batches about 2-3, but not 4.
# - the highest number of batches, value is 4, does not produce highest rejection rate.

# %% [markdown]
# ## summaries
# Following can be summerized from data collected between 2001-2020
# - Total applicants every semester more than 25 requires up to 4 bathes but this not give the highest rejection rate.
# - Number of baches for every semester should be between 2 and 3, it will give optimum rejection rate.
# - Influence of rejection rate should be further investigated in its relation to minimum study duration and students grade.

# %% [markdown]
# ## appendix
# Commands to do the conversion
# + Notebook (ipynb) to LaTeX (tex)
# + LaTeX (tex) to PDF (pdf)

# %%
# !jupyter nbconvert simple_report_on_admission.ipynb --to latex
# Out:
# [NbConvertApp] Converting notebook simple_report_on_admission.ipynb to latex
# [NbConvertApp] Writing 26171 bytes to simple_report_on_admission.tex

# %%
# !xelatex simple_report_on_admission.tex -quiet

# %% [markdown]
# [simple_report_on_admission.pdf](simple_report_on_admission.pdf)
